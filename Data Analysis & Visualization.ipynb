# %% [markdown]
# # Data Analysis and Visualization

# %% [markdown]
# # Univariate Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import re
import time

# %%
df4 = pd.read_csv('Refrigerators_Data4.csv')
df4
# Out:
#     Brand_Name  Capacity_in_Liters    Door_Type  Energy_Efficiency_Rating  \
# 0           LG                 185  Single Door                         4
# 1       Godrej                 180  Single Door                         2
# 2    Whirlpool                 184  Single Door                         2
# 3        Haier                 190  Single Door                         4
# 4    Whirlpool                 192  Single Door                         3
# ..         ...                 ...          ...                       ...
# 571     Godrej                 183  Single Door                         3
# 572         LG                 185  Single Door                         5
# 573     Godrej                 183  Single Door                         2
# 574    SAMSUNG                 236  Double Door                         3
# 575  Whirlpool                 184  Single Door                         2
#
#                  Compressor_type Cooling_Type  Rating  Actual_price  \
# ...

# %%
df4.isnull().sum()
# Out:
# Brand_Name                  0
# Capacity_in_Liters          0
# Door_Type                   0
# Energy_Efficiency_Rating    0
# Compressor_type             0
# Cooling_Type                0
# Rating                      0
# Actual_price                0
# Offer_percentage            0
# Selling_price               0
# dtype: int64

# %%
df4.dtypes
# Out:
# Brand_Name                   object
# Capacity_in_Liters            int64
# Door_Type                    object
# Energy_Efficiency_Rating      int64
# Compressor_type              object
# Cooling_Type                 object
# Rating                      float64
# Actual_price                  int64
# Offer_percentage              int64
# Selling_price                 int64
# dtype: object

# %%
# Pie chat to represent Market Share of Various Refrigerator Brands Within the Dataset

plt.figure(figsize=(6,4))
df4['Brand_Name'].value_counts().plot.pie(autopct='%.2f%%')
plt.title('Market Share of Various Refrigerator Brands Within the Dataset')
plt.show()

# %% [markdown]
# --> The pie chart represents the market share of various refrigerator brands based on their occurrence in the dataset. Here’s the analysis:
#
# 1) Whirlpool has the largest market share, accounting for 31.77% of the refrigerators in the dataset, indicating its significant presence and              popularity among consumers.
# 2) LG follows with a substantial share of 21.01%, reflecting its strong market position.
# 3) Samsung comes next, holding 19.62%, showcasing its competitive stance in the market.
# 4) Godrej has a share of 19.27%, slightly behind Samsung, indicating a comparable preference level.
# 5) Haier and CANDY have the smallest shares, each contributing 4.17%, suggesting their relatively limited presence in the dataset.

# %%
# count of each brand occurance in the dataset
CANDY	24	
Godrej	111
Haier	24	
LG	121
SAMSUNG	113	
Whirlpool	183

# %%
# Box Plot to represent the Distribution of Refrigerator Capacities in Liters
plt.figure(figsize=(5,2))
sns.boxplot(x='Capacity_in_Liters', data = df4)
plt.title('Distribution of Refrigerator Capacities in Liters')
# Out:
# Text(0.5, 1.0, 'Distribution of Refrigerator Capacities in Liters')

# %%
# INTERPRETATION

The graph is box plot, illustrating the distribution of refrigerator capacities in liters:
'Median':
The line inside the box represents the median, which is around 185 liters
'Interquartile Range(IQR)':
The box itself spans the interquartile range, which is the range between the 25th percentile(Q1) and the 75th percentile(Q3).
This indicates that 50% of refrigerators have capacities falling within this range.
'Whiskers':
The lines extending from the box (whiskers) represent the data excluding outliers
'Outliers':
The outliers indicating a refrigerator with a capacity significantly higher than the rest

# %%
# Hist Plot to represent Count of Refrigerators Having Different Type of Doors
plt.figure(figsize=(5,3))
plt.hist(x='Door_Type',data=df4, edgecolor='black')
plt.title('Count of Refrigerators Having Different Type of Doors')
plt.xlabel('Door Type')
plt.ylabel('Count of Refrigerators')
# Out:
# Text(0, 0.5, 'Count of Refrigerators')

# %%
# INTERPRETATION

--> The above graph is a Histogram which gives the information about the Count of Refrigerators Having Different Type of Doors
--> Here, we can see clearly that the majority of refrigerators are of Single Door type (i.e, around 420)
--> Double Door type (i.e, around 100) and Triple Door type (i.e, around 50)

# %%
# Violin Plot to represent Distribution of Refrigerator Energy Efficiency Ratings
plt.figure(figsize=(5,3))
sns.violinplot(x='Energy_Efficiency_Rating', data = df4)
plt.title('Distribution of Refrigerator Energy Efficiency Ratings')
# Out:
# Text(0.5, 1.0, 'Distribution of Refrigerator Energy Efficiency Ratings')

# %%
# INTERPRETATION

--> The plot is a violin plot. It shows the distribution of Energy Efficiency Ratings for refrigerators.
--> The wider section of violin indicates the higher density of data points, while thinner sections of represent lower densities.
--> The white dot in the middle of violin plot represents the median value, and thick black line extends to the first and third quartiles

# %%
# Count Plot for Compressor Type Distribution
plt.figure(figsize=(6,4))
df4['Compressor_type'].value_counts().plot.pie(autopct='%.2f%%')
plt.title('Compressor Type Distribution')
# Out:
# Text(0.5, 1.0, 'Compressor Type Distribution')

# %%
# INTERPRETATION
--> The pie chart depicts the distribution of different compressor types

# %%
# Count Plot for Distribution of Cooling Types
plt.figure(figsize=(5,3))
sns.countplot(x='Cooling_Type', data = df4)
plt.title('Distribution of Cooling Types')
# Out:
# Text(0.5, 1.0, 'Distribution of Cooling Types')

# %%
# INTERPRETATION

--> The plot is a bar chart showing the count of two different cooling types:
-1) Direct Cool : The count of refrigerators is about 410
-2) Frost Free : The count of refrigerators is about 160

# %%
# Hiostogram for Distribution of Rating
plt.figure(figsize=(5,3))
plt.hist(x='Rating',data=df4, bins=6, edgecolor='black')
plt.title('Distribution of Rating')
plt.xlabel('Ratings')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# INTERPRETATION

--> The plot is a histogram showcasing the distribution of ratings:
--> X-Axis represents the rating values, ranging from approximately 4.0 to 4.5
--> Y-Axis display the frequency or count of occurances for each rating interval
--> The height of each bar reflects the no.of data points falling within the corresponding rating range

# %%
# Box Plot for Distribution of Actual Prices
plt.figure(figsize=(5,3))
sns.boxplot(x='Actual_price',data=df4)
plt.title('Distribution of Actual Prices')
# Out:
# Text(0.5, 1.0, 'Distribution of Actual Prices')

# %%
# INTERPRETATION

--> The boxplot is visualizing the distribution of 'Actual_Price' data:
--> The box represents the IQR, which contains the middle 50% of the data. The left most of the box is the first quartile (25%), and the right most of the box is third quartile (75%)
--> The line inside the box represnts the median (50th percentile).
--> The whiskers extend from the box to the minimum and maximum values within 1.5 times of IQR
--> Any data points outside the whiskers are considered outliers but there are no outliers in this plot

# %%
# Density Plot for Distribution of Offer Percentage
plt.figure(figsize=(5,3))
sns.kdeplot(data=df4['Offer_percentage'], fill=True)
plt.title('Distribution of Offer Percentage')
# Out:
# C:\Users\rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribution of Offer Percentage')

# %%
# INTERPRETATION

--> the plot shown is a density plot depicting the distribution of offer percentages for different brands of refrigerators.
--> X-Axis: It shows the range of offer percentages provided on refrigerators, spanning from approximately 10% to 35%
--> Y-Axis: It represents the probability density of the offer percentages.
--> The curve indicates how the offer percentages are distributed across the brands.
--> There is a noticeable peak (mode) around the 25-30% offer range.

# %%
# Violin Plot to represent Distribution of Selling Price
plt.figure(figsize=(5,3))
sns.violinplot(x='Selling_price',data=df4)
plt.title('Distribution of Selling Price')
# Out:
# Text(0.5, 1.0, 'Distribution of Selling Price')

# %%
# INTERPRETATION

--> The plot is a violin plot.
--> The widest part of the violin represents the area where most data points lie, while the thinner parts indicate fewer data points.
--> The shape of this plot suggests a bimodal distribution which means there are two distinct peaks in the data.
--> The white dot inside the black thick line represents the median value of selling prices.
--> The thick black line in the violin shows the Interquartile range(IQR), which encompasses the middle 50% of data.

# %% [markdown]
# # Bi-Variate Analysis
#
# This will help us in understanding the relationship between the variables.

# %%
# Bar plot 
# Categorical vs Categorical variables

plt.figure(figsize=(8,4))
sns.countplot(x='Door_Type', hue='Brand_Name', data = df4)
plt.title('Brand-Wise Distribution of Refrigerator Door Types')
# Out:
# Text(0.5, 1.0, 'Brand-Wise Distribution of Refrigerator Door Types')

# %% [markdown]
# 1) The count plot illustrates the distribution of different refrigerator door types across various brands. Here is an interpretation of the plot:
# 2) The x-axis represents different types of refrigerator doors (Single Door, Double Door, and Triple Door).
# 3) The y-axis shows the count of refrigerators with each door type.

# %% [markdown]
# Key observations:
#
# 1) Single Door refrigerators have the highest count across most brands. Godrej, Whirlpool, and LG show high counts in this category, with relatively    fewer units from brands like Haier and Candy.
# 2) Double Door refrigerators are notably more prominent in brands like Samsung, LG and Whirlpool, while Godrej have very lower counts, and there are no double door refrigerators in Haier and Candy.
# 3) Triple Door refrigerators have the lowest representation overall, with Whirlpool being the only significant contributor.

# %%
# Categorical vs Categorical variables (crosstab)

cross_tab1 = pd.crosstab(df4['Brand_Name'],df4['Compressor_type'])
cross_tab1
# Out:
# Compressor_type  Digital Inverter Compressor  Fixed Speed Compressor  \
# Brand_Name
# CANDY                                      0                       0
# Godrej                                     0                      24
# Haier                                      0                       0
# LG                                         0                       0
# SAMSUNG                                  113                       0
# Whirlpool                                  0                       0
#
# Compressor_type  Inverter Compressor  Normal Compressor  \
# Brand_Name
# CANDY                              0                 24
# Godrej                            87                  0
# Haier                              0                 24
# LG                                 0                  0
# SAMSUNG                            0                  0
# Whirlpool                         49                 40
#
# ...

# %%
# Plotting the bar plot with adjusted figure size
cross_tab1.plot(kind='bar', stacked=True, figsize=(7,4))
plt.legend(title='Offer_percentage', fontsize='small', ncol=2)
plt.title('Stacked Bar Plot of Brand Name vs Compressor Type')
plt.xlabel('Brand Name')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(True)

# %% [markdown]
# 1) The stacked bar plot depicts the distribution of various compressor types across different brands of appliances or products (as indicated by the   labels on the x-axis).
#    Here is an interpretation of the plot:
# 2) The x-axis represents different brand names (Candy, Godrej, Haier, LG, Samsung, and Whirlpool).
# 3) The y-axis shows the count of instances for each compressor type within the brands.
# 4) The legend explains that different colors correspond to different compressor types (e.g., Digital Inverter Compressor, Fixed Speed Compressor, etc.).
# 5) Candy and Haier have a smaller count of compressors compared to other brands, with a prominent representation of the Normal Compressor.

# %%
# Continuous vs Continuous 

colors = ['red', 'blue', 'green', 'yellow', 'purple', 'orange', 'pink', 'brown', 
          'gray', 'cyan', 'magenta', 'lime', 'teal', 'maroon', 'navy', 'olive', 
          'coral', 'gold']
plt.figure(figsize=(6,4))
sns.scatterplot(x='Actual_price', y='Selling_price', hue='Offer_percentage',palette=colors, data=df4)
plt.legend(title='Offer_percentage', fontsize='small', ncol=3)
plt.title('Impact of Offer Percentage on Selling Price')
plt.xticks(rotation=45)
plt.grid(True)

# %% [markdown]
# 1) The scatter plot demonstrates the relationship between certain refrigerator's actual price, selling price, and the offer percentage.
# 2) As the actual price increases, the selling price tends to decrease. This suggests that higher offer percentages are applied to products with higher
#    actual prices, resulting in a lower final selling price.

# %%
# Continuous to Continuous variable (correlation plot)
df4[['Capacity_in_Liters','Selling_price','Offer_percentage']].corr()
# Out:
#                     Capacity_in_Liters  Selling_price  Offer_percentage
# Capacity_in_Liters            1.000000       0.934748          0.391435
# Selling_price                 0.934748       1.000000          0.374406
# Offer_percentage              0.391435       0.374406          1.000000

# %%
plt.figure(figsize=(6,3))
sns.heatmap(df4[['Capacity_in_Liters','Selling_price','Offer_percentage']].corr(),cmap='coolwarm' ,annot=True)
plt.title('Correlation Matrix for Product Attributes')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 1) The heatmap displays the correlation between three variables:
#     a) Capacity in Liters
#     b) Selling Price
#     c) Offer Percentage
#
# 2) There is a strong positive correlation (0.93) between Capacity in Liters and Selling Price, indicating that as the capacity increases,
#     the selling price tends to increase as well.
# 3) A moderate positive correlation exists between Capacity in Liters and Offer Percentage (0.39), suggesting that higher capacity products might
#     have slightly higher offer percentages
# 4) Similarly, there is a moderate positive correlation (0.37) between Selling Price and Offer Percentage, indicating discounts or offers maybe less.

# %%
# Continuous vs Categorical variables
cross_tab = pd.crosstab(df4['Brand_Name'],df4['Rating'])
cross_tab
# Out:
# Rating      3.9  4.1  4.2  4.3  4.4  4.5
# Brand_Name
# CANDY         0   24    0    0    0    0
# Godrej        0   19    2   66   24    0
# Haier         0    0    0    0   24    0
# LG            0    0    0    0   96   25
# SAMSUNG       0    0    0   53   60    0
# Whirlpool    20    0   24  115   24    0

# %%
cross_tab.plot(kind='bar', figsize=(6, 3), width=0.8)
plt.legend(title='Rating', fontsize='small', ncol=2)
plt.title('Brand Rating Comparison')
plt.xticks(rotation=0)
plt.grid(True)

# %% [markdown]
# 1) The bar plot compares brand ratings for different brands. Each bar represents a rating category.
# 2) Whirlpool and LG appear to have higher bars, indicating more products with higher ratings, whereas Candy and Haier have fewer or lower
#    ratings overall.
# 3) This comparision highlights the varying performance and customer ratings across different brands.

# %%
# Continuous vs Categorical
plt.figure(figsize=(8,3))
sns.scatterplot(y='Energy_Efficiency_Rating', x='Selling_price', hue='Brand_Name', data=df4)
plt.legend(title='Brand_Name', fontsize='small', ncol=1)
plt.title('Energy Efficiency Ratings Across Brands with Price Comparision')
# Out:
# Text(0.5, 1.0, 'Energy Efficiency Ratings Across Brands with Price Comparision')

# %% [markdown]
# INTERPRETATION:
#
# --> The scatter plot shows the 'Energy Efficiency Ratings Across Brands with Price Comparision'. It compares different brands based on their Energy Efficiency Ratings and their selling price.
# 1) We can see that most of the data points are falling between ratings of 2 and 5.
# 2) Brands such as LG and Whirlpool tend to have relatively higher energy efficiency ratings and are spread across various price ranges.
# 3) Godrej and Haier models being clustered in certain specific price ranges, instead of being spread out across all price ranges.
#    This indicates that these brands might focus on offering produts within a particular price bracket to target a specific group of customers, like budjet friendly or mid-range buyers.
# 4) Some brands, such as Candy have lower energy efficiency ratings, which are generally priced lower.
#
# 5) The scatter plot suggests that energy efficiency rating and price may have some correlation, where higher ratings might lead to a higher price,
#    though this varies across the brands

# %%
# Bar Plot
# Continuous vs Categorical

plt.figure(figsize=(8,4))
sns.barplot(y='Energy_Efficiency_Rating', x='Brand_Name', hue='Cooling_Type', data=df4, errorbar=None)
plt.title('Energy Efficiency Comparison: Direct Cool vs Frost Free Refrigerators')
# Out:
# Text(0.5, 1.0, 'Energy Efficiency Comparison: Direct Cool vs Frost Free Refrigerators')

# %% [markdown]
# --> The plot is a bar chart comparing the Energy Efficiency Ratings of Different Refrigerator Brands, Categorized by Cooling Type(Direct Cool vs Frost Free)
#
# INTERPRETATION:
#
# --> For most brands, direct cool refrigerators have a higher energy efficiency rating compared to frost free models.
# --> SAMSUNG stands out with the highest energy efficiency rating for Direct Cool type refrigerator.
# --> Whirlpool stands out with the highest energy efficiency rating for Frost Free type refrigerator.
# --> CANDY has the lowest energy efficiency rating for Direct Cool type (have only one type of refrigerator).

# %%
# Continuous vs Catagorical
# pivot table

pivot_table2 = df4.pivot_table(
    index='Brand_Name',
    columns='Capacity_in_Liters',
    values='Selling_price')
#aggfunc='mean'

pivot_table2.head()
# Out:
# Capacity_in_Liters     165      180           183  184           185      190  \
# Brand_Name
# CANDY               9990.0      NaN           NaN  NaN           NaN      NaN
# Godrej                 NaN  13990.0  13522.786885  NaN           NaN      NaN
# Haier                  NaN      NaN           NaN  NaN           NaN  14990.0
# LG                     NaN      NaN           NaN  NaN  16150.659794      NaN
# SAMSUNG                NaN      NaN  17090.000000  NaN           NaN      NaN
#
# Capacity_in_Liters  192  207      215  235           236      238      242  \
# Brand_Name
# CANDY               NaN  NaN      NaN  NaN           NaN      NaN      NaN
# Godrej              NaN  NaN      NaN  NaN           NaN  23990.0      NaN
# Haier               NaN  NaN      NaN  NaN           NaN      NaN      NaN
# LG                  NaN  NaN      NaN  NaN           NaN      NaN  25990.0
# SAMSUNG             NaN  NaN  20690.0  NaN  26565.471698      NaN      NaN
#
# ...

# %%
pivot_table2.plot(kind='bar', figsize=(12,4))
plt.legend(title='Capacity_in_Liters', fontsize='small', ncol=3)
plt.title('Average Refrigerator Price by Brand and Capacity')
plt.ylabel('Selling Price')
plt.grid(True)

# %% [markdown]
# --> The graph illustrates the average selling price of refrigerators across different brands and capacity.
# --> Each bar represents a specific refrigerator model, with the height of the bar indicating its average price.
# --> The X-Axis represents the brand names, while the different colors signify different capacities in liters.
#
# KEY INSIGHTS:
#
# Price and Capacity:
# --> The price generally increases with the refrigerators's capacity.
# --> Larger refrigerators capacity tend to be more expensive.
#
# Brand Variations:
# --> There's a significant price difference between brands, even for refrigerators with similar capacities.
#
# Notable Findings:
#
# --> Whirlpool, LG, SAMSUNG, and Godrej brands dominate the higher price ranges for larger capacities, making them premium options.
#
# --> CANDY and Haier appears to cater to the budget segment.

# %% [markdown]
# CONCLUSION:
#
# This project focused on extracting, cleaning, and visualizing data for various refrigerator brands from the Flipkart website to gain insights into the online marketplace for these products. It highlighted how web scraping can provide access to real-time data that would otherwise be inaccessible.
#
# During the data extraction phase, key details such as brand names, prices, offers, capacities, door types, energy efficiency ratings, and customer ratings were scraped. The unstructured data underwent a rigorous cleaning process, including creating new columns using regular expressions, handling null values by applying statistical methods like mean and median, and fixing data types to ensure consistency and accuracy. This resulted in a robust, organized dataset ready for analysis.
#
# The exploratory data analysis (EDA) and visualization phase provided actionable insights into refrigerator pricing, brand trends, energy efficiency, customer ratings, and door types. By leveraging plots and visual representations, the data revealed valuable patterns, such as the relationship between prices and energy ratings, customer ratings across brands, and preferences for door types. These insights were visualized using univariate, bivariate, and multivariate analyses.
#
# Overall, the project demonstrated the potential of integrating data science techniques to extract and analyze data, delivering value for customers seeking the best refrigerator brands based on their preferences and for businesses aiming to optimize their market strategies. It also underscored the importance of ethical web scraping and adhering to site policies.
